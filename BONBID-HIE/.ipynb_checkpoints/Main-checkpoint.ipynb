# %%
import tensorflow as tf

# TensorFlow 버전 확인
print("TensorFlow version:", tf.__version__)

# GPU 사용 가능 여부 확인
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# TensorFlow version: 2.10.0
# Num GPUs Available:  1

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 11331478909572110491
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 22385000448
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 4986535476026857418
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9"
#  xla_global_id: 416903419]

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import os
import sys

BASE_DIR = os.path.dirname(os.path.abspath(os.path.abspath('')))
WORK_DIR = os.path.join(BASE_DIR, 'code')
sys.path.append(WORK_DIR)
print('base dir: ', BASE_DIR)
# Out:
# base dir:  C:\Users\user\Downloads\BONBID Project

# %%
import tensorflow as tf
import numpy as np
import random

# 난수 시드 설정
seed_value = 42

random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

import tensorflow as tf
import numpy as np
import random
import os

# 난수 시드 설정
seed_value = 42

random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # 첫 번째 GPU 사용 ("0", "1" 등으로 설정 가능)

# GPU 메모리 자동 증가 설정 (필요한 만큼 메모리 할당)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU 메모리 자동 증가 설정 완료")
    except RuntimeError as e:
        print(e)
else:
    print("GPU를 찾을 수 없습니다.")
# Out:
# GPU 메모리 자동 증가 설정 완료

# %%
# 데이터 경로 설정
TRAIN_ADC_CONVERTED_PATH = os.path.join(BASE_DIR, 'data/train/converted/1ADC_ss')
TRAIN_Z_ADC_CONVERTED_PATH = os.path.join(BASE_DIR, 'data/train/converted/2Z_ADC')
TRAIN_LABEL_CONVERTED_PATH = os.path.join(BASE_DIR, 'data/train/converted/3LABEL')
VAL_ADC_CONVERTED_PATH = os.path.join(BASE_DIR, 'data/val/converted/1ADC_ss')
VAL_Z_ADC_CONVERTED_PATH = os.path.join(BASE_DIR, 'data/val/converted/2Z_ADC')
VAL_LABEL_CONVERTED_PATH = os.path.join(BASE_DIR, 'data/val/converted/3LABEL')

# TRAIN_ADC_CONVERTED_PATH = os.path.join(BASE_DIR, 'smalldata/train/converted/1ADC_ss')
# TRAIN_Z_ADC_CONVERTED_PATH = os.path.join(BASE_DIR, 'smalldata/train/converted/2Z_ADC')
# TRAIN_LABEL_CONVERTED_PATH = os.path.join(BASE_DIR, 'smalldata/train/converted/3LABEL')
# VAL_ADC_CONVERTED_PATH = os.path.join(BASE_DIR, 'smalldata/val/converted/1ADC_ss')
# VAL_Z_ADC_CONVERTED_PATH = os.path.join(BASE_DIR, 'smalldata/val/converted/2Z_ADC')
# VAL_LABEL_CONVERTED_PATH = os.path.join(BASE_DIR, 'smalldata/val/converted/3LABEL')

# output_dir = os.path.join(BASE_DIR, 'data/train/processed')
# model_save_dir = os.path.join(project_base_dir, 'small_data/models')

# 모델 저장 디렉토리가 존재하지 않으면 생성
# if not os.path.exists(model_save_dir):
#     os.makedirs(model_save_dir)

# %%
# Grid Search
import sys
from preprocessing import *
from Model import *
from monai.data import DataLoader
import tensorflow as tf
from preprocessing import convert_monai_to_tf_dataset

train_data_path = create_dataset(
    TRAIN_ADC_CONVERTED_PATH,
    TRAIN_Z_ADC_CONVERTED_PATH,
    TRAIN_LABEL_CONVERTED_PATH
)

val_data_path = create_dataset(
    VAL_ADC_CONVERTED_PATH,
    VAL_Z_ADC_CONVERTED_PATH,
    VAL_LABEL_CONVERTED_PATH,
)

unet_model = Unet3DModel(img_height=256, img_width=256, img_depth=64, img_channels=2)

param_grid = {
    'prob_contrast': np.linspace(0.1, 0.9, 9),
    'prob_elastic': np.linspace(0.1, 0.9, 9)
}

best_params, best_score = unet_model.grid_search_prob_tuning(train_data_path, val_data_path, param_grid, epochs=100)
print(f"Best Parameters: {best_params}")
print(f"Best Validation Score: {best_score}")
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image (InputLayer)             [(None, 256, 256, 6  0           []
#                                 4, 2)]
#
#  conv3d (Conv3D)                (None, 256, 256, 64  880         ['image[0][0]']
#                                 , 16)
#
#  batch_normalization (BatchNorm  (None, 256, 256, 64  64         ['conv3d[0][0]']
#  alization)                     , 16)
#
#  activation (Activation)        (None, 256, 256, 64  0           ['batch_normalization[0][0]']
#                                 , 16)
#
#  dropout (Dropout)              (None, 256, 256, 64  0           ['activation[0][0]']
#                                 , 16)
#
#  conv3d_1 (Conv3D)              (None, 256, 256, 64  6928        ['dropout[0][0]']
#                                 , 16)
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 64  64         ['conv3d_1[0][0]']
#  rmalization)                   , 16)
#
#  activation_1 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_1[0][0]']
#                                 , 16)
#
#  max_pooling3d (MaxPooling3D)   (None, 128, 128, 32  0           ['activation_1[0][0]']
#                                 , 16)
#
#  conv3d_2 (Conv3D)              (None, 128, 128, 32  13856       ['max_pooling3d[0][0]']
#                                 , 32)
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 32  128        ['conv3d_2[0][0]']
#  rmalization)                   , 32)
#
#  activation_2 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_2[0][0]']
#                                 , 32)
#
#  dropout_1 (Dropout)            (None, 128, 128, 32  0           ['activation_2[0][0]']
#                                 , 32)
#
#  conv3d_3 (Conv3D)              (None, 128, 128, 32  27680       ['dropout_1[0][0]']
#                                 , 32)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 32  128        ['conv3d_3[0][0]']
#  rmalization)                   , 32)
#
#  activation_3 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_3[0][0]']
#                                 , 32)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 64, 64, 16,   0          ['activation_3[0][0]']
#                                 32)
#
#  conv3d_4 (Conv3D)              (None, 64, 64, 16,   55360       ['max_pooling3d_1[0][0]']
#                                 64)
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 16,   256        ['conv3d_4[0][0]']
#  rmalization)                   64)
#
#  activation_4 (Activation)      (None, 64, 64, 16,   0           ['batch_normalization_4[0][0]']
#                                 64)
#
#  dropout_2 (Dropout)            (None, 64, 64, 16,   0           ['activation_4[0][0]']
#                                 64)
#
#  conv3d_5 (Conv3D)              (None, 64, 64, 16,   110656      ['dropout_2[0][0]']
#                                 64)
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 16,   256        ['conv3d_5[0][0]']
#  rmalization)                   64)
#
#  activation_5 (Activation)      (None, 64, 64, 16,   0           ['batch_normalization_5[0][0]']
#                                 64)
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 32, 32, 8, 6  0          ['activation_5[0][0]']
#                                 4)
#
#  conv3d_6 (Conv3D)              (None, 32, 32, 8, 1  221312      ['max_pooling3d_2[0][0]']
#                                 28)
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 8, 1  512        ['conv3d_6[0][0]']
#  rmalization)                   28)
#
#  activation_6 (Activation)      (None, 32, 32, 8, 1  0           ['batch_normalization_6[0][0]']
#                                 28)
#
#  dropout_3 (Dropout)            (None, 32, 32, 8, 1  0           ['activation_6[0][0]']
#                                 28)
#
#  conv3d_7 (Conv3D)              (None, 32, 32, 8, 1  442496      ['dropout_3[0][0]']
#                                 28)
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 8, 1  512        ['conv3d_7[0][0]']
#  rmalization)                   28)
#
#  activation_7 (Activation)      (None, 32, 32, 8, 1  0           ['batch_normalization_7[0][0]']
#                                 28)
#
#  max_pooling3d_3 (MaxPooling3D)  (None, 16, 16, 4, 1  0          ['activation_7[0][0]']
#                                 28)
#
#  conv3d_8 (Conv3D)              (None, 16, 16, 4, 2  884992      ['max_pooling3d_3[0][0]']
#                                 56)
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 4, 2  1024       ['conv3d_8[0][0]']
#  rmalization)                   56)
#
#  activation_8 (Activation)      (None, 16, 16, 4, 2  0           ['batch_normalization_8[0][0]']
#                                 56)
#
#  dropout_4 (Dropout)            (None, 16, 16, 4, 2  0           ['activation_8[0][0]']
#                                 56)
#
#  conv3d_9 (Conv3D)              (None, 16, 16, 4, 2  1769728     ['dropout_4[0][0]']
#                                 56)
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 4, 2  1024       ['conv3d_9[0][0]']
#  rmalization)                   56)
#
#  activation_9 (Activation)      (None, 16, 16, 4, 2  0           ['batch_normalization_9[0][0]']
#                                 56)
#
#  conv3d_transpose (Conv3DTransp  (None, 32, 32, 8, 1  262272     ['activation_9[0][0]']
#  ose)                           28)
#
#  concatenate (Concatenate)      (None, 32, 32, 8, 2  0           ['conv3d_transpose[0][0]',
#                                 56)                               'activation_7[0][0]']
#
#  conv3d_10 (Conv3D)             (None, 32, 32, 8, 1  884864      ['concatenate[0][0]']
#                                 28)
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 8, 1  512        ['conv3d_10[0][0]']
#  ormalization)                  28)
#
#  activation_10 (Activation)     (None, 32, 32, 8, 1  0           ['batch_normalization_10[0][0]']
#                                 28)
#
#  dropout_5 (Dropout)            (None, 32, 32, 8, 1  0           ['activation_10[0][0]']
#                                 28)
#
#  conv3d_11 (Conv3D)             (None, 32, 32, 8, 1  442496      ['dropout_5[0][0]']
#                                 28)
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 8, 1  512        ['conv3d_11[0][0]']
#  ormalization)                  28)
#
#  activation_11 (Activation)     (None, 32, 32, 8, 1  0           ['batch_normalization_11[0][0]']
#                                 28)
#
#  conv3d_transpose_1 (Conv3DTran  (None, 64, 64, 16,   65600      ['activation_11[0][0]']
#  spose)                         64)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 16,   0           ['conv3d_transpose_1[0][0]',
#                                 128)                              'activation_5[0][0]']
#
#  conv3d_12 (Conv3D)             (None, 64, 64, 16,   221248      ['concatenate_1[0][0]']
#                                 64)
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 16,   256        ['conv3d_12[0][0]']
#  ormalization)                  64)
#
#  activation_12 (Activation)     (None, 64, 64, 16,   0           ['batch_normalization_12[0][0]']
#                                 64)
#
#  dropout_6 (Dropout)            (None, 64, 64, 16,   0           ['activation_12[0][0]']
#                                 64)
#
#  conv3d_13 (Conv3D)             (None, 64, 64, 16,   110656      ['dropout_6[0][0]']
#                                 64)
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 16,   256        ['conv3d_13[0][0]']
#  ormalization)                  64)
#
#  activation_13 (Activation)     (None, 64, 64, 16,   0           ['batch_normalization_13[0][0]']
#                                 64)
#
#  conv3d_transpose_2 (Conv3DTran  (None, 128, 128, 32  16416      ['activation_13[0][0]']
#  spose)                         , 32)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 32  0           ['conv3d_transpose_2[0][0]',
#                                 , 64)                             'activation_3[0][0]']
#
#  conv3d_14 (Conv3D)             (None, 128, 128, 32  55328       ['concatenate_2[0][0]']
#                                 , 32)
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 32  128        ['conv3d_14[0][0]']
#  ormalization)                  , 32)
#
#  activation_14 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_14[0][0]']
#                                 , 32)
#
#  dropout_7 (Dropout)            (None, 128, 128, 32  0           ['activation_14[0][0]']
#                                 , 32)
#
#  conv3d_15 (Conv3D)             (None, 128, 128, 32  27680       ['dropout_7[0][0]']
#                                 , 32)
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 32  128        ['conv3d_15[0][0]']
#  ormalization)                  , 32)
#
#  activation_15 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_15[0][0]']
#                                 , 32)
#
#  conv3d_transpose_3 (Conv3DTran  (None, 256, 256, 64  4112       ['activation_15[0][0]']
#  spose)                         , 16)
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 64  0           ['conv3d_transpose_3[0][0]',
#                                 , 32)                             'activation_1[0][0]']
#
#  conv3d_16 (Conv3D)             (None, 256, 256, 64  13840       ['concatenate_3[0][0]']
#                                 , 16)
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 64  64         ['conv3d_16[0][0]']
#  ormalization)                  , 16)
#
#  activation_16 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_16[0][0]']
#                                 , 16)
#
#  dropout_8 (Dropout)            (None, 256, 256, 64  0           ['activation_16[0][0]']
#                                 , 16)
#
#  conv3d_17 (Conv3D)             (None, 256, 256, 64  6928        ['dropout_8[0][0]']
#                                 , 16)
#
#  batch_normalization_17 (BatchN  (None, 256, 256, 64  64         ['conv3d_17[0][0]']
#  ormalization)                  , 16)
#
#  activation_17 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_17[0][0]']
#                                 , 16)
#
#  conv3d_18 (Conv3D)             (None, 256, 256, 64  17          ['activation_17[0][0]']
#                                 , 1)
#
# ==================================================================================================
# Total params: 5,651,233
# Trainable params: 5,648,289
# Non-trainable params: 2,944
# __________________________________________________________________________________________________
# Training with prob_contrast=0.1, prob_elastic=0.1
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image (InputLayer)             [(None, 256, 256, 6  0           []
#                                 4, 2)]
#
#  conv3d_19 (Conv3D)             (None, 256, 256, 64  880         ['image[0][0]']
#                                 , 16)
#
#  batch_normalization_18 (BatchN  (None, 256, 256, 64  64         ['conv3d_19[0][0]']
#  ormalization)                  , 16)
#
#  activation_18 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_18[0][0]']
#                                 , 16)
#
#  dropout_9 (Dropout)            (None, 256, 256, 64  0           ['activation_18[0][0]']
#                                 , 16)
#
#  conv3d_20 (Conv3D)             (None, 256, 256, 64  6928        ['dropout_9[0][0]']
#                                 , 16)
#
#  batch_normalization_19 (BatchN  (None, 256, 256, 64  64         ['conv3d_20[0][0]']
#  ormalization)                  , 16)
#
#  activation_19 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_19[0][0]']
#                                 , 16)
#
#  max_pooling3d_4 (MaxPooling3D)  (None, 128, 128, 32  0          ['activation_19[0][0]']
#                                 , 16)
#
#  conv3d_21 (Conv3D)             (None, 128, 128, 32  13856       ['max_pooling3d_4[0][0]']
#                                 , 32)
#
#  batch_normalization_20 (BatchN  (None, 128, 128, 32  128        ['conv3d_21[0][0]']
#  ormalization)                  , 32)
#
#  activation_20 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_20[0][0]']
#                                 , 32)
#
#  dropout_10 (Dropout)           (None, 128, 128, 32  0           ['activation_20[0][0]']
#                                 , 32)
#
#  conv3d_22 (Conv3D)             (None, 128, 128, 32  27680       ['dropout_10[0][0]']
#                                 , 32)
#
#  batch_normalization_21 (BatchN  (None, 128, 128, 32  128        ['conv3d_22[0][0]']
#  ormalization)                  , 32)
#
#  activation_21 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_21[0][0]']
#                                 , 32)
#
#  max_pooling3d_5 (MaxPooling3D)  (None, 64, 64, 16,   0          ['activation_21[0][0]']
#                                 32)
#
#  conv3d_23 (Conv3D)             (None, 64, 64, 16,   55360       ['max_pooling3d_5[0][0]']
#                                 64)
#
#  batch_normalization_22 (BatchN  (None, 64, 64, 16,   256        ['conv3d_23[0][0]']
#  ormalization)                  64)
#
#  activation_22 (Activation)     (None, 64, 64, 16,   0           ['batch_normalization_22[0][0]']
#                                 64)
#
#  dropout_11 (Dropout)           (None, 64, 64, 16,   0           ['activation_22[0][0]']
#                                 64)
#
#  conv3d_24 (Conv3D)             (None, 64, 64, 16,   110656      ['dropout_11[0][0]']
#                                 64)
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 16,   256        ['conv3d_24[0][0]']
#  ormalization)                  64)
#
#  activation_23 (Activation)     (None, 64, 64, 16,   0           ['batch_normalization_23[0][0]']
#                                 64)
#
#  max_pooling3d_6 (MaxPooling3D)  (None, 32, 32, 8, 6  0          ['activation_23[0][0]']
#                                 4)
#
#  conv3d_25 (Conv3D)             (None, 32, 32, 8, 1  221312      ['max_pooling3d_6[0][0]']
#                                 28)
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 8, 1  512        ['conv3d_25[0][0]']
#  ormalization)                  28)
#
#  activation_24 (Activation)     (None, 32, 32, 8, 1  0           ['batch_normalization_24[0][0]']
#                                 28)
#
#  dropout_12 (Dropout)           (None, 32, 32, 8, 1  0           ['activation_24[0][0]']
#                                 28)
#
#  conv3d_26 (Conv3D)             (None, 32, 32, 8, 1  442496      ['dropout_12[0][0]']
#                                 28)
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 8, 1  512        ['conv3d_26[0][0]']
#  ormalization)                  28)
#
#  activation_25 (Activation)     (None, 32, 32, 8, 1  0           ['batch_normalization_25[0][0]']
#                                 28)
#
#  max_pooling3d_7 (MaxPooling3D)  (None, 16, 16, 4, 1  0          ['activation_25[0][0]']
#                                 28)
#
#  conv3d_27 (Conv3D)             (None, 16, 16, 4, 2  884992      ['max_pooling3d_7[0][0]']
#                                 56)
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 4, 2  1024       ['conv3d_27[0][0]']
#  ormalization)                  56)
#
#  activation_26 (Activation)     (None, 16, 16, 4, 2  0           ['batch_normalization_26[0][0]']
#                                 56)
#
#  dropout_13 (Dropout)           (None, 16, 16, 4, 2  0           ['activation_26[0][0]']
#                                 56)
#
#  conv3d_28 (Conv3D)             (None, 16, 16, 4, 2  1769728     ['dropout_13[0][0]']
#                                 56)
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 4, 2  1024       ['conv3d_28[0][0]']
#  ormalization)                  56)
#
#  activation_27 (Activation)     (None, 16, 16, 4, 2  0           ['batch_normalization_27[0][0]']
#                                 56)
#
#  conv3d_transpose_4 (Conv3DTran  (None, 32, 32, 8, 1  262272     ['activation_27[0][0]']
#  spose)                         28)
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 8, 2  0           ['conv3d_transpose_4[0][0]',
#                                 56)                               'activation_25[0][0]']
#
#  conv3d_29 (Conv3D)             (None, 32, 32, 8, 1  884864      ['concatenate_4[0][0]']
#                                 28)
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 8, 1  512        ['conv3d_29[0][0]']
#  ormalization)                  28)
#
#  activation_28 (Activation)     (None, 32, 32, 8, 1  0           ['batch_normalization_28[0][0]']
#                                 28)
#
#  dropout_14 (Dropout)           (None, 32, 32, 8, 1  0           ['activation_28[0][0]']
#                                 28)
#
#  conv3d_30 (Conv3D)             (None, 32, 32, 8, 1  442496      ['dropout_14[0][0]']
#                                 28)
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 8, 1  512        ['conv3d_30[0][0]']
#  ormalization)                  28)
#
#  activation_29 (Activation)     (None, 32, 32, 8, 1  0           ['batch_normalization_29[0][0]']
#                                 28)
#
#  conv3d_transpose_5 (Conv3DTran  (None, 64, 64, 16,   65600      ['activation_29[0][0]']
#  spose)                         64)
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 16,   0           ['conv3d_transpose_5[0][0]',
#                                 128)                              'activation_23[0][0]']
#
#  conv3d_31 (Conv3D)             (None, 64, 64, 16,   221248      ['concatenate_5[0][0]']
#                                 64)
#
#  batch_normalization_30 (BatchN  (None, 64, 64, 16,   256        ['conv3d_31[0][0]']
#  ormalization)                  64)
#
#  activation_30 (Activation)     (None, 64, 64, 16,   0           ['batch_normalization_30[0][0]']
#                                 64)
#
#  dropout_15 (Dropout)           (None, 64, 64, 16,   0           ['activation_30[0][0]']
#                                 64)
#
#  conv3d_32 (Conv3D)             (None, 64, 64, 16,   110656      ['dropout_15[0][0]']
#                                 64)
#
#  batch_normalization_31 (BatchN  (None, 64, 64, 16,   256        ['conv3d_32[0][0]']
#  ormalization)                  64)
#
#  activation_31 (Activation)     (None, 64, 64, 16,   0           ['batch_normalization_31[0][0]']
#                                 64)
#
#  conv3d_transpose_6 (Conv3DTran  (None, 128, 128, 32  16416      ['activation_31[0][0]']
#  spose)                         , 32)
#
#  concatenate_6 (Concatenate)    (None, 128, 128, 32  0           ['conv3d_transpose_6[0][0]',
#                                 , 64)                             'activation_21[0][0]']
#
#  conv3d_33 (Conv3D)             (None, 128, 128, 32  55328       ['concatenate_6[0][0]']
#                                 , 32)
#
#  batch_normalization_32 (BatchN  (None, 128, 128, 32  128        ['conv3d_33[0][0]']
#  ormalization)                  , 32)
#
#  activation_32 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_32[0][0]']
#                                 , 32)
#
#  dropout_16 (Dropout)           (None, 128, 128, 32  0           ['activation_32[0][0]']
#                                 , 32)
#
#  conv3d_34 (Conv3D)             (None, 128, 128, 32  27680       ['dropout_16[0][0]']
#                                 , 32)
#
#  batch_normalization_33 (BatchN  (None, 128, 128, 32  128        ['conv3d_34[0][0]']
#  ormalization)                  , 32)
#
#  activation_33 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_33[0][0]']
#                                 , 32)
#
#  conv3d_transpose_7 (Conv3DTran  (None, 256, 256, 64  4112       ['activation_33[0][0]']
#  spose)                         , 16)
#
#  concatenate_7 (Concatenate)    (None, 256, 256, 64  0           ['conv3d_transpose_7[0][0]',
#                                 , 32)                             'activation_19[0][0]']
#
#  conv3d_35 (Conv3D)             (None, 256, 256, 64  13840       ['concatenate_7[0][0]']
#                                 , 16)
#
#  batch_normalization_34 (BatchN  (None, 256, 256, 64  64         ['conv3d_35[0][0]']
#  ormalization)                  , 16)
#
#  activation_34 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_34[0][0]']
#                                 , 16)
#
#  dropout_17 (Dropout)           (None, 256, 256, 64  0           ['activation_34[0][0]']
#                                 , 16)
#
#  conv3d_36 (Conv3D)             (None, 256, 256, 64  6928        ['dropout_17[0][0]']
#                                 , 16)
#
#  batch_normalization_35 (BatchN  (None, 256, 256, 64  64         ['conv3d_36[0][0]']
#  ormalization)                  , 16)
#
#  activation_35 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_35[0][0]']
#                                 , 16)
#
#  conv3d_37 (Conv3D)             (None, 256, 256, 64  17          ['activation_35[0][0]']
#                                 , 1)
#
# ==================================================================================================
# Total params: 5,651,233
# Trainable params: 5,648,289
# Non-trainable params: 2,944
# __________________________________________________________________________________________________
# Epoch 1/2
#       2/Unknown - 19s 249ms/step - loss: 0.9328 - accuracy: 0.2490 - mean_io_u_1: 0.4836 - dice_coefficient: 0.0667
# Epoch 1: val_dice_coefficient improved from -inf to 0.08634, saving model to /content/drive/MyDrive/Colab Notebooks/BONBID Project/models\best_dice_model.keras
# 2/2 [==============================] - 20s 1s/step - loss: 0.9328 - accuracy: 0.2490 - mean_io_u_1: 0.4836 - dice_coefficient: 0.0667 - val_loss: 0.9146 - val_accuracy: 0.2275 - val_mean_io_u_1: 0.5240 - val_dice_coefficient: 0.0863
# Epoch 2/2
# 2/2 [==============================] - ETA: 0s - loss: 0.8789 - accuracy: 0.7334 - mean_io_u_1: 0.4836 - dice_coefficient: 0.1209
# Epoch 2: val_dice_coefficient did not improve from 0.08634
# 2/2 [==============================] - 2s 859ms/step - loss: 0.8789 - accuracy: 0.7334 - mean_io_u_1: 0.4836 - dice_coefficient: 0.1209 - val_loss: 0.9236 - val_accuracy: 0.1939 - val_mean_io_u_1: 0.5321 - val_dice_coefficient: 0.0762
# Training with prob_contrast=0.1, prob_elastic=0.5
# Model: "model_2"
# ...
#
#  dropout_84 (Dropout)           (None, 32, 32, 8, 1  0           ['activation_168[0][0]']
#                                 28)
#
#  conv3d_178 (Conv3D)            (None, 32, 32, 8, 1  442496      ['dropout_84[0][0]']
#                                 28)
#
#  batch_normalization_169 (Batch  (None, 32, 32, 8, 1  512        ['conv3d_178[0][0]']
#  Normalization)                 28)
#
#  activation_169 (Activation)    (None, 32, 32, 8, 1  0           ['batch_normalization_169[0][0]']
#                                 28)
#
#  max_pooling3d_39 (MaxPooling3D  (None, 16, 16, 4, 1  0          ['activation_169[0][0]']
#  )                              28)
#
#  conv3d_179 (Conv3D)            (None, 16, 16, 4, 2  884992      ['max_pooling3d_39[0][0]']
#                                 56)
#
#  batch_normalization_170 (Batch  (None, 16, 16, 4, 2  1024       ['conv3d_179[0][0]']
#  Normalization)                 56)
#
#  activation_170 (Activation)    (None, 16, 16, 4, 2  0           ['batch_normalization_170[0][0]']
#                                 56)
#
#  dropout_85 (Dropout)           (None, 16, 16, 4, 2  0           ['activation_170[0][0]']
#                                 56)
#
#  conv3d_180 (Conv3D)            (None, 16, 16, 4, 2  1769728     ['dropout_85[0][0]']
#                                 56)
#
#  batch_normalization_171 (Batch  (None, 16, 16, 4, 2  1024       ['conv3d_180[0][0]']
#  Normalization)                 56)
#
#  activation_171 (Activation)    (None, 16, 16, 4, 2  0           ['batch_normalization_171[0][0]']
#                                 56)
#
#  conv3d_transpose_36 (Conv3DTra  (None, 32, 32, 8, 1  262272     ['activation_171[0][0]']
#  nspose)                        28)
#
#  concatenate_36 (Concatenate)   (None, 32, 32, 8, 2  0           ['conv3d_transpose_36[0][0]',
#                                 56)                               'activation_169[0][0]']
#
#  conv3d_181 (Conv3D)            (None, 32, 32, 8, 1  884864      ['concatenate_36[0][0]']
#                                 28)
#
#  batch_normalization_172 (Batch  (None, 32, 32, 8, 1  512        ['conv3d_181[0][0]']
#  Normalization)                 28)
#
#  activation_172 (Activation)    (None, 32, 32, 8, 1  0           ['batch_normalization_172[0][0]']
#                                 28)
#
#  dropout_86 (Dropout)           (None, 32, 32, 8, 1  0           ['activation_172[0][0]']
#                                 28)
#
#  conv3d_182 (Conv3D)            (None, 32, 32, 8, 1  442496      ['dropout_86[0][0]']
#                                 28)
#
#  batch_normalization_173 (Batch  (None, 32, 32, 8, 1  512        ['conv3d_182[0][0]']
#  Normalization)                 28)
#
#  activation_173 (Activation)    (None, 32, 32, 8, 1  0           ['batch_normalization_173[0][0]']
#                                 28)
#
#  conv3d_transpose_37 (Conv3DTra  (None, 64, 64, 16,   65600      ['activation_173[0][0]']
#  nspose)                        64)
#
#  concatenate_37 (Concatenate)   (None, 64, 64, 16,   0           ['conv3d_transpose_37[0][0]',
#                                 128)                              'activation_167[0][0]']
#
#  conv3d_183 (Conv3D)            (None, 64, 64, 16,   221248      ['concatenate_37[0][0]']
#                                 64)
#
#  batch_normalization_174 (Batch  (None, 64, 64, 16,   256        ['conv3d_183[0][0]']
#  Normalization)                 64)
#
#  activation_174 (Activation)    (None, 64, 64, 16,   0           ['batch_normalization_174[0][0]']
#                                 64)
#
#  dropout_87 (Dropout)           (None, 64, 64, 16,   0           ['activation_174[0][0]']
#                                 64)
#
#  conv3d_184 (Conv3D)            (None, 64, 64, 16,   110656      ['dropout_87[0][0]']
#                                 64)
#
#  batch_normalization_175 (Batch  (None, 64, 64, 16,   256        ['conv3d_184[0][0]']
#  Normalization)                 64)
#
#  activation_175 (Activation)    (None, 64, 64, 16,   0           ['batch_normalization_175[0][0]']
#                                 64)
#
#  conv3d_transpose_38 (Conv3DTra  (None, 128, 128, 32  16416      ['activation_175[0][0]']
#  nspose)                        , 32)
#
#  concatenate_38 (Concatenate)   (None, 128, 128, 32  0           ['conv3d_transpose_38[0][0]',
#                                 , 64)                             'activation_165[0][0]']
#
#  conv3d_185 (Conv3D)            (None, 128, 128, 32  55328       ['concatenate_38[0][0]']
#                                 , 32)
#
#  batch_normalization_176 (Batch  (None, 128, 128, 32  128        ['conv3d_185[0][0]']
#  Normalization)                 , 32)
#
#  activation_176 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_176[0][0]']
#                                 , 32)
#
#  dropout_88 (Dropout)           (None, 128, 128, 32  0           ['activation_176[0][0]']
#                                 , 32)
#
#  conv3d_186 (Conv3D)            (None, 128, 128, 32  27680       ['dropout_88[0][0]']
#                                 , 32)
#
#  batch_normalization_177 (Batch  (None, 128, 128, 32  128        ['conv3d_186[0][0]']
#  Normalization)                 , 32)
#
#  activation_177 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_177[0][0]']
#                                 , 32)
#
#  conv3d_transpose_39 (Conv3DTra  (None, 256, 256, 64  4112       ['activation_177[0][0]']
#  nspose)                        , 16)
#
#  concatenate_39 (Concatenate)   (None, 256, 256, 64  0           ['conv3d_transpose_39[0][0]',
#                                 , 32)                             'activation_163[0][0]']
#
#  conv3d_187 (Conv3D)            (None, 256, 256, 64  13840       ['concatenate_39[0][0]']
#                                 , 16)
#
#  batch_normalization_178 (Batch  (None, 256, 256, 64  64         ['conv3d_187[0][0]']
#  Normalization)                 , 16)
#
#  activation_178 (Activation)    (None, 256, 256, 64  0           ['batch_normalization_178[0][0]']
#                                 , 16)
#
#  dropout_89 (Dropout)           (None, 256, 256, 64  0           ['activation_178[0][0]']
#                                 , 16)
#
#  conv3d_188 (Conv3D)            (None, 256, 256, 64  6928        ['dropout_89[0][0]']
#                                 , 16)
#
#  batch_normalization_179 (Batch  (None, 256, 256, 64  64         ['conv3d_188[0][0]']
#  Normalization)                 , 16)
#
#  activation_179 (Activation)    (None, 256, 256, 64  0           ['batch_normalization_179[0][0]']
#                                 , 16)
#
#  conv3d_189 (Conv3D)            (None, 256, 256, 64  17          ['activation_179[0][0]']
#                                 , 1)
#
# ==================================================================================================
# Total params: 5,651,233
# Trainable params: 5,648,289
# Non-trainable params: 2,944
# __________________________________________________________________________________________________
# Epoch 1/2
#       2/Unknown - 3s 437ms/step - loss: 0.8957 - accuracy: 0.5217 - mean_io_u_9: 0.4836 - dice_coefficient: 0.1027
# Epoch 1: val_dice_coefficient improved from -inf to 0.08615, saving model to /content/drive/MyDrive/Colab Notebooks/BONBID Project/models\best_dice_model.keras
# 2/2 [==============================] - 4s 1s/step - loss: 0.8957 - accuracy: 0.5217 - mean_io_u_9: 0.4836 - dice_coefficient: 0.1027 - val_loss: 0.9147 - val_accuracy: 0.3203 - val_mean_io_u_9: 0.5170 - val_dice_coefficient: 0.0861
# Epoch 2/2
# 2/2 [==============================] - ETA: 0s - loss: 0.8504 - accuracy: 0.8262 - mean_io_u_9: 0.4836 - dice_coefficient: 0.1493
# Epoch 2: val_dice_coefficient did not improve from 0.08615
# 2/2 [==============================] - 2s 1s/step - loss: 0.8504 - accuracy: 0.8262 - mean_io_u_9: 0.4836 - dice_coefficient: 0.1493 - val_loss: 0.9216 - val_accuracy: 0.2745 - val_mean_io_u_9: 0.4695 - val_dice_coefficient: 0.0779
# Best Parameters: {'prob_contrast': 0.5, 'prob_elastic': 0.9}
# Best Validation Score: 0.10705672949552536

# %%
# # 데이터셋 로드
# import sys
# from preprocessing import create_and_preprocess_dataset
# from monai.data import DataLoader
# import tensorflow as tf
# from preprocessing import convert_monai_to_tf_dataset

# train_monai_dataset = create_and_preprocess_dataset(
#     TRAIN_ADC_CONVERTED_PATH,
#     TRAIN_Z_ADC_CONVERTED_PATH,
#     TRAIN_LABEL_CONVERTED_PATH,
#     is_train=True
# )

# val_monai_dataset = create_and_preprocess_dataset(
#     VAL_ADC_CONVERTED_PATH,
#     VAL_Z_ADC_CONVERTED_PATH,
#     VAL_LABEL_CONVERTED_PATH,
#     is_train=False
# )

# # Convert MONAI datasets to TensorFlow datasets
# train_tf_dataloader = convert_monai_to_tf_dataset(train_monai_dataset, batch_size=1)
# val_tf_dataloader = convert_monai_to_tf_dataset(val_monai_dataset, batch_size=1)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# # GPU 메모리 설정
# def set_gpu_memory_growth():
#     gpus = tf.config.experimental.list_physical_devices('GPU')
#     if gpus:
#         try:
#             for gpu in gpus:
#                 tf.config.experimental.set_memory_growth(gpu, True)
#             print(f"Enabled memory growth for {len(gpus)} GPU(s)")
#         except RuntimeError as e:
#             print(e)

# %%
# import matplotlib.pyplot as plt

# # 결과 시각화 함수
# def plot_history(history):
#     epochs_range = range(1, len(history.history['loss']) + 1)

#     plt.figure(figsize=(14, 10))

#     plt.subplot(2, 2, 1)
#     plt.plot(epochs_range, history.history['loss'], 'ro-', label='Training Loss')
#     plt.plot(epochs_range, history.history['val_loss'], 'bo-', label='Validation Loss')
#     plt.title('Training and Validation Loss')
#     plt.xlabel('Epoch')
#     plt.ylabel('Loss')
#     plt.legend()

#     plt.subplot(2, 2, 2)
#     plt.plot(epochs_range, history.history['accuracy'], 'ro-', label='Training Accuracy')
#     plt.plot(epochs_range, history.history['val_accuracy'], 'bo-', label='Validation Accuracy')
#     plt.title('Training and Validation Accuracy')
#     plt.xlabel('Epoch')
#     plt.ylabel('Accuracy')
#     plt.legend()

#     plt.subplot(2, 2, 3)
#     plt.plot(epochs_range, history.history['mean_io_u'], 'ro-', label='Training Mean IoU')
#     plt.plot(epochs_range, history.history['val_mean_io_u'], 'bo-', label='Validation Mean IoU')
#     plt.title('Training and Validation Mean IoU')
#     plt.xlabel('Epoch')
#     plt.ylabel('Mean IoU')
#     plt.legend()

#     plt.subplot(2, 2, 4)
#     plt.plot(epochs_range, history.history['dice_coefficient'], 'ro-', label='Training Dice Coefficient')
#     plt.plot(epochs_range, history.history['val_dice_coefficient'], 'bo-', label='Validation Dice Coefficient')
#     plt.title('Training and Validation Dice Coefficient')
#     plt.xlabel('Epoch')
#     plt.ylabel('Dice Coefficient')
#     plt.legend()

#     plt.tight_layout()
#     plt.show()

# %%
# from Model import Unet3DModel

# # 모델 훈련 및 결과 시각화
# def train_and_evaluate_model(train_tf_dataloader, val_tf_dataloader, img_height=256, img_width=256, img_depth=64, img_channels=2, batch_size=1, epochs=100):
#     set_gpu_memory_growth()
#     model = Unet3DModel(img_height=img_height, img_width=img_width, img_depth=img_depth, img_channels=img_channels)

#     # 모델 훈련
#     history = model.train(train_tf_dataloader, val_tf_dataloader, batch_size=batch_size, epochs=epochs)

#     # 결과 시각화
#     plot_history(history)

# %%
# train_and_evaluate_model(train_tf_dataloader, val_tf_dataloader)

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.metrics import MeanIoU
import numpy as np
from tensorflow.keras.models import load_model
from Model import DiceLoss, DiceCoefficient

# 저장된 모델 로드
model = load_model('/content/drive/MyDrive/Colab Notebooks/BONBID Project/models/best_dice_model.keras', custom_objects={'MeanIoU': MeanIoU, 'DiceCoefficient': DiceCoefficient, 'DiceLoss': DiceLoss})

# 모델 평가
def evaluate_model(model, val_tf_dataloader):
    results = model.evaluate(val_tf_dataloader)
    print(f"Validation Loss: {results[0]}")
    print(f"Validation Accuracy: {results[1]}")
    print(f"Mean IoU: {results[2]}")
    print(f"Dice Coefficient: {results[3]}")

evaluate_model(model, val_tf_dataloader)

# %%
import matplotlib.pyplot as plt
import numpy as np

def visualize_predictions(model, val_tf_dataloader, num_samples=4):
    fig, axes = plt.subplots(num_samples, 4, figsize=(20, 5 * num_samples))

    for i, (data, label) in enumerate(val_tf_dataloader.take(num_samples)):
        prediction = model.predict(data)
        image = data.numpy().squeeze()
        label = label.numpy().squeeze()
        prediction = prediction.squeeze()

        # 이진화 과정 추가
        threshold = 0.5
        prediction_binary = (prediction >= threshold).astype(np.float32)

        slice_idx = image.shape[2] // 2  # 중앙 슬라이스 선택

        # 첫 번째 채널의 입력 이미지 시각화
        axes[i, 0].imshow(image[:, :, slice_idx, 0], cmap='gray')
        axes[i, 0].set_title('Input Image - Channel 1')
        axes[i, 0].axis('off')

        # 두 번째 채널의 입력 이미지 시각화
        axes[i, 1].imshow(image[:, :, slice_idx, 1], cmap='gray')
        axes[i, 1].set_title('Input Image - Channel 2')
        axes[i, 1].axis('off')

        # 실제 마스크 시각화
        axes[i, 2].imshow(label[:, :, slice_idx], cmap='gray')
        axes[i, 2].set_title('True Mask')
        axes[i, 2].axis('off')

        # 예측된 마스크 시각화
        axes[i, 3].imshow(prediction_binary[:, :, slice_idx], cmap='gray')
        axes[i, 3].set_title('Predicted Mask')
        axes[i, 3].axis('off')

    plt.tight_layout()
    plt.show()

visualize_predictions(model, val_tf_dataloader, num_samples=4)
